% %%
%% load data 
% G = readtable('Glc.csv');

T = readtable('Latest20170208.xlsx');
% Out:
% 警告: 有効な MATLAB 識別子になるように変数名が変更されました。

% %%
%% remove subjects HFA reliability is low
rows =  T.FP< .15 & T.FN<.33 & T.FixLoss_pcnt<.2;
% rows =  T.FP< .15 & T.FixLoss_pcnt<.2;


T2 = T(rows,:);

figure; hold on;
subplot(1,2,1)
plot(T2.CSFI,T2.MD30_2,'*r') % n = 575
title 'Good HFA n =572 '  
xlabel CSFI
ylabel MD30-2

subplot(1,2,2)
plot(T.CSFI,T.MD30_2,'*') % n = 661
title 'all subject n=661' 
xlabel CSFI
ylabel MD30-2

% %%
size(T2.CSFI) % n of selected subjects
% Out:
% ans =
%
%    572     1

% %%
%% NTG vs POAG
Type = char(T2.Type);
rows = zeros(length(T2.Type),1);

% Pick up POAG
for n = 1: length(T2.Type);
 rows(n) = strcmp(T2.Type(n),'POAG');
 rows    = logical(rows);
end

POAG = T2(rows,:);

% pick up NTG
for n = 1: length(T2.Type);
 rows(n) = strcmp(T2.Type(n),'NTG');
 rows    = logical(rows);
end
NTG  =  T2(rows,:);

% %%
%% patients charastarics

mean(NTG.age)
nanstd(NTG.age)
%sprintf('NTG mean age = %d sd %d',mean(NTG.age),nanstd(NTG.age))

mean(POAG.age)
nanstd(POAG.age)

mean(NTG.MD30_2)
mean(POAG.MD30_2)
p = ranksum(POAG.MD30_2,NTG.MD30_2)


mean(NTG.VFI)
mean(POAG.VFI)
std(NTG.VFI)

p = ranksum(POAG.VFI,NTG.VFI)
% Out:
% ans =
%
%    57.3141
%
%
% ans =
%
%    11.2114
%
%
% ans =
%
%    59.3424
%
%
% ans =
%
%    12.2035
%
%
% ans =
%
%    -5.9997
%
%
% ans =
%
%    -7.1058
%
%
% p =
%
%     0.1762
%
%
% ans =
%
%     0.8351
%
%
% ans =
%
%     0.7924
%
%
% ans =
%
%     0.1815
%
%
% p =
%
%     0.1678

% %%
%% Gender 

[tbl,chi2,p,labels] = crosstab(T2.Type,T2.Gender)
[h,p,stats] = fishertest(tbl)
% Out:
% tbl =
%
%    192   103
%    180    97
%
%
% chi2 =
%
%    6.6387e-04
%
%
% p =
%
%     0.9794
%
%
% labels =
%
%     'POAG'    'M'
%     'NTG'     'F'
%
%
% h =
%
%      0
%
%
% p =
%
%     1.0000
%
%
% stats =
%
%              OddsRatio: 1.0045
%     ConfidenceInterval: [0.7122 1.4168]

% %%
%% NTG vs POAG 
figure; hold on;
plot(NTG.CSFI, NTG.MD30_2,'*r')
plot(POAG.CSFI,POAG.MD30_2,'*b')


title 'NTG vs POAG' 
xlabel CSFI
ylabel MD30-2

legend({'NTG','POAG'})

% %%
%% ANCOV shows that there is no difference due to glc type
% this note book can not use these function below

% [h,atab,ctab,stats] = aoctool(T2.CSFI, T2.MD30_2,T2.Type);

% [h,atab,ctab,stats] = aoctool(T2.CSFI, T2.VFI,T2.Type);

% %%
%% CSFI vs MD
figure; hold on;
% scatter(T2.CSFI,T2.MD30_2,10,'*')

plot(NTG.CSFI, NTG.VFI,'*r')
plot(POAG.CSFI,POAG.VFI,'*b')
xlabel CSFI
ylabel VFI
legend({'NTG','POAG'})
hold off

% %%
%% CSFI vs MD
% AIC; akaike model returns how many number of function ('nanji kansu') fit well to the data, AIC lower is better 

n = 10;
AIC = zeros(1,n);
obj = cell(1,n);
for k = 1:n
%     figure; hold on;
%     plot(NTG.CSFI, NTG.MD30_2,'*r')
%     plot(POAG.CSFI,POAG.MD30_2,'*b')
    obj{k} = gmdistribution.fit([T2.CSFI,T2.MD30_2],k);
    AIC(k)= obj{k}.AIC;

% h = ezcontour(@(x,y)pdf(obj{k},[x y]));
% axis auto
end
figure; hold on;
plot(AIC,'r.')
line([0 10],[min(AIC),min(AIC)])
title AIC
% Out:
% 警告: 4 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 5 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 6 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 7 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 8 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 9 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 10 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)

% %%
%% AIC VFI
n = 10;
AIC = zeros(1,n);
obj = cell(1,n);
for k = 1:n
    obj{k} = gmdistribution.fit([T2.CSFI,T2.MD30_2],k);
    AIC(k)= obj{k}.AIC;
end

figure; hold on;
plot(AIC,'r.')
line([0 10],[min(AIC),min(AIC)])
title AIC
hold off
% h = ezcontour(@(x,y)pdf(obj{1},[x y]));
% Out:
% 警告: 4 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 5 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 6 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 7 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 8 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 9 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 10 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)

% %%
%% Fitting exponential dose not fit 

[estimates, model] = fitcurvedemo(T2.CSFI,T2.VFI);

figure; hold on;
plot(T2.CSFI,T2.VFI, '*')
% hold on
[sse, FittedCurve] = model(estimates);
plot(T2.CSFI, FittedCurve, 'r')
 
xlabel('CSFI')
ylabel('f(estimates,T2.CSFI)')
title(['Fitting to function ', func2str(model)]);
legend('data', ['fit using ', func2str(model)])
hold off

% %%
% Just correlation between whole CSFI vs MD, VFI
[h,p] = corrcoef(T2.CSFI,T2.VFI) % VFI
[h,p] = corrcoef(T2.CSFI,T2.MD30_2) % MD
% Out:
% h =
%
%     1.0000   -0.8533
%    -0.8533    1.0000
%
%
% p =
%
%     1.0000    0.0000
%     0.0000    1.0000
%
%
% h =
%
%     1.0000   -0.8904
%    -0.8904    1.0000
%
%
% p =
%
%     1.0000    0.0000
%     0.0000    1.0000

% %%
%% CSFI vs MD30-2
% fit model No of functions 
n =5;
for jj = 1:n
figure; hold on;
c = lines(n);
plot(T2.CSFI,T2.MD30_2,'*b')
[p,ErrorEst] = polyfit(T2.CSFI,T2.MD30_2,jj);

t2 = linspace(-0.4,1);
[y2,delta] = polyval(p,t2,ErrorEst);

% 95% c.i.
plot(t2,y2,'color',c(jj,:))
plot(t2,y2+2*delta,'r:')
plot(t2,y2-2*delta,'r:')

xlabel 'CSFI %'
ylabel MD
title(sprintf('FIT %d function with CI',jj))
hold off;
end

% %%
%% lowess show CSFI is greater than cpRNFL; Medeirous et al. already show this.
figure; hold on;
yy2 = smooth(T2.CSFI,T2.MD30_2,0.3,'rloess');
% plot(yy2)
[xx,ind] = sort(T2.CSFI);
plot(xx,T2.MD30_2(ind),'b.',xx,yy2(ind),'r-')
xlabel 'CSFI'
ylabel MD
% legend({'POAG','2d','3d','4d'}

figure;
yy3 = smooth(T2.cpRNFL,T2.MD30_2,0.4,'rloess');
[xx,ind] = sort(T2.cpRNFL);
plot(T2.cpRNFL,T2.MD30_2,'b.',xx,yy3(ind),'r-')
xlabel 'cpRNFL'
ylabel MD

% %%
%% lowess show CSFI is greater than cpRNFL

figure; hold on;
yy2 = smooth(T2.CSFI,T2.VFI,0.3,'rloess');
% plot(yy2)
[xx,ind] = sort(T2.CSFI);
plot(xx,T2.VFI(ind),'b.',xx,yy2(ind),'r-')
xlabel 'CSFI'
ylabel 'VFI'
% legend({'POAG','2d','3d','4d'}

figure;
yy3 = smooth(T2.cpRNFL,T2.VFI,0.4,'rloess');
[xx,ind] = sort(T2.cpRNFL);
plot(T2.cpRNFL,T2.VFI,'b.',xx,yy3(ind),'r-')
xlabel 'cpRNFL'
ylabel 'VFI'

% %%
%% CSFI vs VFI
% AIC 
n = 10;
AIC = zeros(1,n);
obj = cell(1,n);
for k = 1:n
    obj{k} = gmdistribution.fit([T2.CSFI,T2.VFI],k);
    AIC(k)= obj{k}.AIC;
end

figure; hold on;
plot(AIC,'r.')
line([0 10],[min(AIC),min(AIC)]) % lowest is best model
% title AIC
xlabel 'N of function'
ylabel AIC
hold off

% 
% AIC
% min(AIC)

% h = ezcontour(@(x,y)pdf(obj{4},[x y]));
% axis auto
% Out:
% 警告: 5 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 6 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 7 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 8 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 9 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)
% 警告: 10 成分をもつ gmdistribution が 100 回の反復で収束しませんでした。
% > In gmcluster (line 198)
%   In gmdistribution.fit (line 95)

% %%
% 6 is best
n = 6;
for jj = 1:n
figure; hold on;
c = lines(n);
plot(T2.CSFI,T2.VFI,'*b')
[p,ErrorEst] = polyfit(T2.CSFI,T2.VFI,jj);

t2 = linspace(-0.4,1);
[y2,delta] = polyval(p,t2,ErrorEst);

% 95% c.i.
plot(t2,y2,'color',c(jj,:))
plot(t2,y2+2*delta,'r:')
plot(t2,y2-2*delta,'r:')

xlabel CSFI
ylabel VFI
title(sprintf('FIT %d function with CI',jj))
hold off;
end

% %%
%% staging
inds = T2.MD30_2>-6; 
ninds = NTG.MD30_2>-6;
pinds = POAG.MD30_2>-6;

figure;hold on;

plot(NTG.CSFI(ninds), NTG.MD30_2(ninds),'*r')
plot(POAG.CSFI(pinds),POAG.MD30_2(pinds),'*b')


% plot(x,y,'o','color',[0 0 0])%,'MarkerFaceColor',c(1,:))
% plot(x,y,'*b')%,'MarkerFaceColor',c(1,:))

xlabel CSFI
ylabel MD
title Early
legend({'NTG','POAG'})

% lsline
x = T2.CSFI(inds);
y = T2.MD30_2(inds);
mdl = fitlm(x,y)
[h,p] = corrcoef(x, y)
% title Early


% VFI


figure;hold on;
% plot(x,y,'o','color',[0 0 0])%,'MarkerFaceColor',c(1,:))
plot(NTG.CSFI(ninds), NTG.VFI(ninds),'*r')
plot(POAG.CSFI(pinds),POAG.VFI(pinds),'*b')
xlabel CSFI
ylabel VFI
title Early
legend({'NTG','POAG'})

% title Early
% lsline
x = T2.CSFI(inds);
y = T2.VFI(inds);
mdl = fitlm(x,y)

[h,p] = corrcoef(x, y)
% Out:
% mdl =
%
%
% 線形回帰モデル:
%     y ~ 1 + x1
%
% 推定された係数:
%                    Estimate      SE        tStat       pValue
%                    ________    _______    _______    __________
%
%     (Intercept)    -0.14564    0.11891    -1.2248       0.22152
%     x1              -8.8114    0.44193    -19.938    9.1577e-59
%
%
% 観測数: 335、誤差の自由度: 333
% 二乗平均平方根誤差: 1.31
% 決定係数: 0.544、自由度調整済み決定係数 0.543
% F 統計量と一定のモデルの比較: 398、p 値は 9.16e-59 です
%
% h =
%
%     1.0000   -0.7377
%    -0.7377    1.0000
%
%
% p =
%
%     1.0000    0.0000
%     0.0000    1.0000
%
%
% mdl =
%
%
% 線形回帰モデル:
%     y ~ 1 + x1
%
% 推定された係数:
%                    Estimate       SE         tStat       pValue
%                    ________    _________    _______    __________
%
%     (Intercept)    0.99079     0.0037199     266.35             0
%     x1             -0.1886      0.013825    -13.642    5.7291e-34
%
%
% 観測数: 335、誤差の自由度: 333
% 二乗平均平方根誤差: 0.0409
% 決定係数: 0.359、自由度調整済み決定係数 0.357
% F 統計量と一定のモデルの比較: 186、p 値は 5.73e-34 です
%
% h =
%
%     1.0000   -0.5988
%    -0.5988    1.0000
%
%
% p =
%
%     1.0000    0.0000
%     0.0000    1.0000

% %%
%% stage 2
inds = T2.MD30_2<-6 & T2.MD30_2>=-12 ; 
ninds = NTG.MD30_2<-6 & NTG.MD30_2>=-12 ; 
pinds = POAG.MD30_2<-6 & POAG.MD30_2>=-12 ; 

figure;hold on;

plot(NTG.CSFI(ninds), NTG.MD30_2(ninds),'*r')
plot(POAG.CSFI(pinds),POAG.MD30_2(pinds),'*b')

xlabel CSFI
ylabel MD
title Middle
legend({'NTG','POAG'})


x = T2.CSFI(inds);
y = T2.MD30_2(inds);

mdl = fitlm(x,y)

[h,p] = corrcoef(x, y)


% VFI
y = T2.VFI(inds);

figure; hold on;
plot(NTG.CSFI(ninds), NTG.VFI(ninds),'*r')
plot(POAG.CSFI(pinds),POAG.VFI(pinds),'*b')

xlabel CSFI
ylabel VFI
title Middle
legend({'NTG','POAG'})

% figure;hold on;
% plot(x,y,'o','color',[0 0 0])%,'MarkerFaceColor',c(1,:))
% xlabel CSFI
% ylabel VFI
% 
% title Middle
% lsline

mdl = fitlm(x,y)

[h,p] = corr(x, y)
% Out:
% mdl =
%
%
% 線形回帰モデル:
%     y ~ 1 + x1
%
% 推定された係数:
%                    Estimate      SE        tStat       pValue
%                    ________    _______    _______    __________
%
%     (Intercept)    -4.0673     0.91572    -4.4416    2.0501e-05
%     x1             -9.3022      1.8382    -5.0606    1.5847e-06
%
%
% 観測数: 118、誤差の自由度: 116
% 二乗平均平方根誤差: 1.6
% 決定係数: 0.181、自由度調整済み決定係数 0.174
% F 統計量と一定のモデルの比較: 25.6、p 値は 1.58e-06 です
%
% h =
%
%     1.0000   -0.4253
%    -0.4253    1.0000
%
%
% p =
%
%     1.0000    0.0000
%     0.0000    1.0000
%
%
% mdl =
%
%
% 線形回帰モデル:
%     y ~ 1 + x1
%
% 推定された係数:
%                    Estimate       SE        tStat       pValue
%                    ________    ________    _______    __________
%
%     (Intercept)     0.91175    0.048028     18.984    2.2127e-37
%     x1             -0.30483    0.096408    -3.1619     0.0020008
%
%
% 観測数: 118、誤差の自由度: 116
% 二乗平均平方根誤差: 0.0837
% 決定係数: 0.0793、自由度調整済み決定係数 0.0714
% F 統計量と一定のモデルの比較: 10、p 値は 0.002 です
%
% h =
%
%    -0.2817
%
%
% p =
%
%     0.0020

% %%
%% stage 3
inds = T2.MD30_2<-12 ; 
ninds = NTG.MD30_2<-12 ; 
pinds = POAG.MD30_2<-12 ; 

% MD
figure;hold on;

plot(NTG.CSFI(ninds), NTG.MD30_2(ninds),'*r')
plot(POAG.CSFI(pinds),POAG.MD30_2(pinds),'*b')

xlabel CSFI
ylabel MD
title Advanced
legend({'NTG','POAG'})

x = T2.CSFI(inds);
y = T2.MD30_2(inds);

mdl = fitlm(x,y)

[h,p] = corrcoef(x,y)


% VFI
y = T2.VFI(inds);

figure; hold on;
plot(NTG.CSFI(ninds), NTG.VFI(ninds),'*r')
plot(POAG.CSFI(pinds),POAG.VFI(pinds),'*b')

xlabel CSFI
ylabel VFI
title Advanced
legend({'NTG','POAG'})

%x = T2.CSFI(inds);
y = T2.VFI(inds);

mdl = fitlm(x,y)

[h,p] = corrcoef(x,y)
% Out:
% mdl =
%
%
% 線形回帰モデル:
%     y ~ 1 + x1
%
% 推定された係数:
%                    Estimate      SE       tStat       pValue
%                    ________    ______    _______    __________
%
%     (Intercept)     3.8147     1.5357     2.4841      0.014404
%     x1             -30.126     2.1678    -13.897    1.5902e-26
%
%
% 観測数: 119、誤差の自由度: 117
% 二乗平均平方根誤差: 2.6
% 決定係数: 0.623、自由度調整済み決定係数 0.62
% F 統計量と一定のモデルの比較: 193、p 値は 1.59e-26 です
%
% h =
%
%     1.0000   -0.7891
%    -0.7891    1.0000
%
%
% p =
%
%     1.0000    0.0000
%     0.0000    1.0000
%
%
% mdl =
%
%
% 線形回帰モデル:
%     y ~ 1 + x1
%
% 推定された係数:
%                    Estimate       SE        tStat       pValue
%                    ________    ________    _______    __________
%
%     (Intercept)     1.3204     0.052009     25.389    2.0454e-49
%     x1             -1.2043     0.073417    -16.403    4.1076e-32
%
%
% 観測数: 119、誤差の自由度: 117
% 二乗平均平方根誤差: 0.0879
% 決定係数: 0.697、自由度調整済み決定係数 0.694
% F 統計量と一定のモデルの比較: 269、p 値は 4.11e-32 です
%
% h =
%
%     1.0000   -0.8348
%    -0.8348    1.0000
%
%
% p =
%
%     1.0000    0.0000
%     0.0000    1.0000

% %%
% linear regression
tbl = table(T2.CSFI,T2.age,T2.AL,T2.cpRNFL,T2.FixLoss_pcnt,T2.Gender,T2.VFI,T2.MD30_2,...
    'VariableNames',{'CSFI','age','AL','cpRNFL','Fix_Loss','Gender','VFI','MD'});

lm = fitlm(tbl,'CSFI ~ 1 + VFI + age + cpRNFL')

lm = fitlm(tbl,'CSFI ~ 1 + MD + age + cpRNFL')
% Out:
% lm =
%
%
% 線形回帰モデル:
%     CSFI ~ 1 + age + cpRNFL + VFI
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    ___________
%
%     (Intercept)        1.7253      0.027383     63.005    1.7692e-258
%     age            -0.0019555    0.00029329    -6.6676     6.1696e-11
%     cpRNFL          -0.008925     0.0003285    -27.169    8.7442e-105
%     VFI              -0.71457      0.019613    -36.433    9.3667e-151
%
%
% 観測数: 572、誤差の自由度: 568
% 二乗平均平方根誤差: 0.0824
% 決定係数: 0.885、自由度調整済み決定係数 0.885
% F 統計量と一定のモデルの比較: 1.46e+03、p 値は 9.74e-267 です
%
% lm =
%
%
% 線形回帰モデル:
%     CSFI ~ 1 + age + cpRNFL + MD
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    ___________
%
%     (Intercept)       0.87692      0.029678     29.548     6.338e-117
%     age            -0.0012593    0.00026248    -4.7976     2.0552e-06
%     cpRNFL         -0.0080079    0.00030231    -26.489    2.7558e-101
%     MD               -0.02423    0.00057101    -42.433    2.9055e-178
%
%
% 観測数: 572、誤差の自由度: 568
% 二乗平均平方根誤差: 0.0737
% 決定係数: 0.908、自由度調整済み決定係数 0.908
% F 統計量と一定のモデルの比較: 1.88e+03、p 値は 3.19e-294 です

% %%
% linear regression
tbl = table(T2.CSFI,T2.age,T2.AL,T2.cpRNFL,T2.FixLoss_pcnt,T2.Gender,T2.MD30_2,...
    'VariableNames',{'CSFI','age','AL','cpRNFL','Fix_Loss','Gender','MD'});

lm = fitlm(tbl)


tbl = table(T2.CSFI,T2.age,T2.AL,T2.cpRNFL,T2.FixLoss_pcnt,T2.Gender,T2.VFI,...
    'VariableNames',{'CSFI','age','AL','cpRNFL','Fix_Loss','Gender','VFI'});

lm = fitlm(tbl)

% Fix loss, AL, Gneder is not important
% Out:
% lm =
%
%
% 線形回帰モデル:
%     MD ~ 1 + CSFI + age + AL + cpRNFL + Fix_Loss + Gender
%
% 推定された係数:
%                    Estimate        SE        tStat       pValue
%                    _________    ________    _______    __________
%
%     (Intercept)       16.237      2.4469      6.636    1.3838e-10
%     CSFI             -30.935      1.0096    -30.642     4.702e-97
%     age            -0.031564    0.013301    -2.3731      0.018233
%     AL              0.094086    0.059576     1.5793       0.11527
%     cpRNFL          -0.16533    0.019065     -8.672    2.1934e-16
%     Fix_Loss          2.3129       2.697    0.85758       0.39177
%     Gender_F         0.61494     0.32144     1.9131      0.056634
%
%
% 観測数: 326、誤差の自由度: 319
% 二乗平均平方根誤差: 2.66
% 決定係数: 0.832、自由度調整済み決定係数 0.829
% F 統計量と一定のモデルの比較: 264、p 値は 2.17e-120 です
%
% lm =
%
%
% 線形回帰モデル:
%     VFI ~ 1 + CSFI + age + AL + cpRNFL + Fix_Loss + Gender
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    __________
%
%     (Intercept)        1.6034      0.087196     18.388    5.3938e-52
%     CSFI             -0.96123      0.035977    -26.718    2.2139e-83
%     age            -0.0019575    0.00047399    -4.1299    4.6398e-05
%     AL               0.004402      0.002123     2.0735      0.038932
%     cpRNFL         -0.0059012     0.0006794    -8.6859    1.9861e-16
%     Fix_Loss         0.056837       0.09611    0.59138       0.55469
%     Gender_F         0.013692      0.011455     1.1953       0.23285
%
%
% 観測数: 326、誤差の自由度: 319
% 二乗平均平方根誤差: 0.0949
% 決定係数: 0.778、自由度調整済み決定係数 0.773
% F 統計量と一定のモデルの比較: 186、p 値は 5.54e-101 です

% %%
% linear regression

% MD =
tbl = table(T2.CSFI,T2.age,T2.AL,T2.cpRNFL,T2.Gender,T2.MD30_2,...
    'VariableNames',{'CSFI','age','AL','cpRNFL','Gender','MD'});

lm = fitlm(tbl)

% VFI =
tbl = table(T2.CSFI,T2.age,T2.AL,T2.cpRNFL,T2.Gender,T2.VFI,...
    'VariableNames',{'CSFI','age','AL','cpRNFL','Gender','VFI'});

lm = fitlm(tbl)
%lm = fitlm(tbl,'CSFI ~ 1 + MD + age + cpRNFL')
% Out:
% lm =
%
%
% 線形回帰モデル:
%     MD ~ 1 + CSFI + age + AL + cpRNFL + Gender
%
% 推定された係数:
%                    Estimate        SE        tStat       pValue
%                    _________    ________    _______    __________
%
%     (Intercept)       16.294      2.4449     6.6645    1.1625e-10
%     CSFI             -30.948       1.009    -30.671    2.7412e-97
%     age            -0.030467    0.013234    -2.3022      0.021965
%     AL              0.095134    0.059539     1.5978       0.11106
%     cpRNFL          -0.16569    0.019053    -8.6964     1.824e-16
%     Gender_F         0.60607     0.32114     1.8872      0.060035
%
%
% 観測数: 326、誤差の自由度: 320
% 二乗平均平方根誤差: 2.66
% 決定係数: 0.832、自由度調整済み決定係数 0.829
% F 統計量と一定のモデルの比較: 316、p 値は 1.67e-121 です
%
% lm =
%
%
% 線形回帰モデル:
%     VFI ~ 1 + CSFI + age + AL + cpRNFL + Gender
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    __________
%
%     (Intercept)        1.6048      0.087076      18.43    3.3461e-52
%     CSFI             -0.96155      0.035936    -26.757    1.2569e-83
%     age            -0.0019306    0.00047131    -4.0962     5.327e-05
%     AL              0.0044278     0.0021204     2.0882      0.037574
%     cpRNFL           -0.00591    0.00067855    -8.7098    1.6578e-16
%     Gender_F         0.013474      0.011437     1.1781       0.23964
%
%
% 観測数: 326、誤差の自由度: 320
% 二乗平均平方根誤差: 0.0948
% 決定係数: 0.777、自由度調整済み決定係数 0.774
% F 統計量と一定のモデルの比較: 224、p 値は 4.19e-102 です

% %%
%% staging
inds = T2.MD30_2>-6; 
Early = T2(inds,:);

inds = T2.MD30_2<-6 & T2.MD30_2>=-12 ; 
Middle = T2(inds,:);

inds = T2.MD30_2<-12 ; 
End  = T2(inds,:);

% %%
%% Early
tbl = table(Early.CSFI,Early.age,Early.AL,Early.cpRNFL,Early.FixLoss_pcnt,...
    Early.Gender,Early.VFI,Early.MD30_2,...
    'VariableNames',{'CSFI','age','AL','cpRNFL','Fix_Loss','Gender','VFI','MD'});

lm = fitlm(tbl,'CSFI ~ 1 + VFI + age + cpRNFL')
% anova(lm,'summary')

lm = fitlm(tbl,'CSFI ~ 1 + MD + age + cpRNFL')
% Out:
% lm =
%
%
% 線形回帰モデル:
%     CSFI ~ 1 + age + cpRNFL + VFI
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    __________
%
%     (Intercept)        2.1276      0.077485     27.458    2.4554e-87
%     age            -0.0025794    0.00033117    -7.7886     8.798e-14
%     cpRNFL         -0.0098552    0.00037415     -26.34    3.1362e-83
%     VFI               -1.0365      0.084816    -12.221    1.3406e-28
%
%
% 観測数: 335、誤差の自由度: 331
% 二乗平均平方根誤差: 0.0724
% 決定係数: 0.802、自由度調整済み決定係数 0.801
% F 統計量と一定のモデルの比較: 448、p 値は 4.05e-116 です
%
% lm =
%
%
% 線形回帰モデル:
%     CSFI ~ 1 + age + cpRNFL + MD
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    __________
%
%     (Intercept)       0.92476      0.033052     27.979    3.1735e-89
%     age            -0.0014082    0.00027423    -5.1352    4.8201e-07
%     cpRNFL         -0.0089219    0.00031201    -28.595     1.927e-91
%     MD              -0.037337     0.0018823    -19.836    2.9658e-58
%
%
% 観測数: 335、誤差の自由度: 331
% 二乗平均平方根誤差: 0.0589
% 決定係数: 0.869、自由度調整済み決定係数 0.868
% F 統計量と一定のモデルの比較: 731、p 値は 1.23e-145 です

% %%
%% Middle
tbl = table(Middle.CSFI,Middle.age,Middle.AL,Middle.cpRNFL,Middle.FixLoss_pcnt,...
    Middle.Gender,Middle.VFI,Middle.MD30_2,...
    'VariableNames',{'CSFI','age','AL','cpRNFL','Fix_Loss','Gender','VFI','MD'});

lm = fitlm(tbl,'CSFI ~ 1 + VFI + age + cpRNFL')
lm = fitlm(tbl,'CSFI ~ 1 + MD + age + cpRNFL')
% Out:
% lm =
%
%
% 線形回帰モデル:
%     CSFI ~ 1 + age + cpRNFL + VFI
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    __________
%
%     (Intercept)        1.1069        0.0649     17.055    3.7029e-33
%     age            -0.0013245    0.00046888    -2.8248     0.0055866
%     cpRNFL         -0.0056617    0.00056688    -9.9874    2.9721e-17
%     VFI              -0.19104      0.060488    -3.1583     0.0020314
%
%
% 観測数: 118、誤差の自由度: 114
% 二乗平均平方根誤差: 0.0561
% 決定係数: 0.525、自由度調整済み決定係数 0.512
% F 統計量と一定のモデルの比較: 42、p 値は 2.37e-18 です
%
% lm =
%
%
% 線形回帰モデル:
%     CSFI ~ 1 + age + cpRNFL + MD
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    __________
%
%     (Intercept)       0.81586      0.054122     15.074     6.586e-29
%     age            -0.0013292    0.00043768    -3.0369     0.0029631
%     cpRNFL         -0.0054024    0.00053397    -10.117    1.4771e-17
%     MD              -0.014795     0.0028126    -5.2601    6.8226e-07
%
%
% 観測数: 118、誤差の自由度: 114
% 二乗平均平方根誤差: 0.0524
% 決定係数: 0.584、自由度調整済み決定係数 0.573
% F 統計量と一定のモデルの比較: 53.4、p 値は 1.24e-21 です

% %%
%% Advanced
tbl = table(End.CSFI,End.age,End.AL,End.cpRNFL,End.FixLoss_pcnt,...
    End.Gender,End.VFI,End.MD30_2,...
    'VariableNames',{'CSFI','age','AL','cpRNFL','Fix_Loss','Gender','VFI','MD'});

lm = fitlm(tbl,'CSFI ~ 1 + VFI + age + cpRNFL')
lm = fitlm(tbl,'CSFI ~ 1 + MD + age + cpRNFL')
% Out:
% lm =
%
%
% 線形回帰モデル:
%     CSFI ~ 1 + age + cpRNFL + VFI
%
% 推定された係数:
%                     Estimate         SE         tStat       pValue
%                    __________    __________    _______    __________
%
%     (Intercept)        1.1753      0.046132     25.476    4.1359e-49
%     age            -0.0013408    0.00044239    -3.0307     0.0030141
%     cpRNFL           -0.00191    0.00059956    -3.1857      0.001859
%     VFI               -0.5793      0.032951    -17.581    2.2362e-34
%
%
% 観測数: 119、誤差の自由度: 115
% 二乗平均平方根誤差: 0.0564
% 決定係数: 0.745、自由度調整済み決定係数 0.738
% F 統計量と一定のモデルの比較: 112、p 値は 5.47e-34 です
%
% lm =
%
%
% 線形回帰モデル:
%     CSFI ~ 1 + age + cpRNFL + MD
%
% 推定された係数:
%                     Estimate          SE         tStat       pValue
%                    ___________    __________    _______    __________
%
%     (Intercept)        0.47403      0.061205     7.7449    4.1121e-12
%     age            -0.00062736    0.00052257    -1.2005        0.2324
%     cpRNFL          -0.0013726     0.0007181    -1.9114      0.058443
%     MD               -0.020216     0.0014842    -13.621    9.6371e-26
%
%
% 観測数: 119、誤差の自由度: 115
% 二乗平均平方根誤差: 0.067
% 決定係数: 0.64、自由度調整済み決定係数 0.631
% F 統計量と一定のモデルの比較: 68.2、p 値は 2.02e-25 です
